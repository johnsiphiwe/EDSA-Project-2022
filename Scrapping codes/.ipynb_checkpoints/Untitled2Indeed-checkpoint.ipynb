# %%
#https://www.indeed.com/jobs?q=data%20science&vjk=112aad486886a532

# %%
#https://www.indeed.com/jobs?q=data%20science&start&vjk=186d713c08e65295

# %%
#libraries needed for webscrapping

import requests # request accesing pages
from bs4 import BeautifulSoup # to scrape html code from pages
import pandas as pd # to create a data frame
import numpy as np # generate random times for pauses between requests 
import re
import string
from datetime import datetime

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://www.indeed.com/jobs?q=data%20science&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
       # try:
            #company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list1.append(jobs)
    return

# %%
job_list1 = []
c = extract(0)
transform(c)
print(len(job_list1))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,650,10):
    c = extract(0)
    transform(c)

# %%
test  = pd.DataFrame(job_list1)
test
# Out:
#                                                  title company  \
# 0                                  CO-OP, DATA SCIENCE    PUMA
# 1                                  newData Scientist 1    PUMA
# 2                      Data Science Associate (Remote)    PUMA
# 3    Front End Engineer, MADS- Measurement and Data...    PUMA
# 4                    Seasonal Assistant - Data Analyst    PUMA
# ..                                                 ...     ...
# 985                         newData Science Specialist    PUMA
# 986                           Data Science & Analytics    PUMA
# 987                                   newData Engineer    PUMA
# 988                 Data Science Analyst - 100% Remote    PUMA
# 989                            Associate, Data Science    PUMA
#
#            location                                           job_desc  \
# 0    Somerville, MA  Leveraging internal and external data to ident...
# 1    Somerville, MA  Applies knowledge of statistics, mathematics, ...
# 2    Somerville, MA  Bachelor/Master Degree students pursuing degre...
# 3    Somerville, MA  Professional non-internship experience with fr...
# 4    Somerville, MA  Create new automation solutions for business d...
# ..              ...                                                ...
# 985  Somerville, MA  A bachelor’s degree in computer science, data ...
# 986  Somerville, MA  As much as you’re a master at rigorous mining,...
# 987  Somerville, MA  Proactive data pipeline monitoring to ensure d...
# 988  Somerville, MA  The Data Analyst proactively participates in d...
# 989  Somerville, MA  Learn the use and limitations of data from var...
#
#             date_posted date_scrapped          salary  \
# 0    Posted30+ days ago    2022-05-19  $93,800 a year
# 1    Posted30+ days ago    2022-05-19  $93,800 a year
# 2    Posted30+ days ago    2022-05-19  $93,800 a year
# 3    Posted30+ days ago    2022-05-19  $93,800 a year
# 4    Posted30+ days ago    2022-05-19  $93,800 a year
# ..                  ...           ...             ...
# 985  Posted30+ days ago    2022-05-19  $93,800 a year
# 986  Posted30+ days ago    2022-05-19  $93,800 a year
# 987  Posted30+ days ago    2022-05-19  $93,800 a year
# 988  Posted30+ days ago    2022-05-19  $93,800 a year
# 989  Posted30+ days ago    2022-05-19  $93,800 a year
#
#                                                job_url
# 0    https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 1    https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 2    https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 3    https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 4    https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# ..                                                 ...
# 985  https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 986  https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 987  https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 988  https://www.indeed.com/rc/clk?jk=16330f4d1e351...
# 989  https://www.indeed.com/rc/clk?jk=16330f4d1e351...
#
# [990 rows x 8 columns]

# %%
print(jobs)

# %%
print(company)

# %%
print(jobs)

# %% [markdown]
# ###  Indeed jobs
#
# ### Remote
#
#
# #### Search word: Data scientist = Remote

# %%
https://www.indeed.com/jobs?q=data%20scientist&l=Remote&ts=1651547016072&rs=1&vjk=d4892583d4d1b6b9

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://www.indeed.com/jobs?q=data%20scientist&l=Remote&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list2.append(jobs)
    return

# %%
job_list2 = []
c = extract(0)
transform(c)
print(len(job_list2))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,330,10):
    c = extract(0)
    transform(c)

# %%
remote  = pd.DataFrame(job_list2)
remote
# Out:
#                                                  title company  \
# 0                                    newData Scientist  Toyota
# 1                              Data Scientist (Remote)  Toyota
# 2                                       Data Scientist  Toyota
# 3                                  newData Scientist 1  Toyota
# 4                                    newData Scientist  Toyota
# ..                                                 ...     ...
# 505  Data Scientist II - Algorithmic Justice Specia...  Toyota
# 506                                     Data Scientist  Toyota
# 507                                  newData Scientist  Toyota
# 508                            Data Scientist (Remote)  Toyota
# 509                                  newData Scientist  Toyota
#
#                                  location  \
# 0    Remote in Plano, TX 75023+1 location
# 1    Remote in Plano, TX 75023+1 location
# 2    Remote in Plano, TX 75023+1 location
# 3    Remote in Plano, TX 75023+1 location
# 4    Remote in Plano, TX 75023+1 location
# ..                                    ...
# 505  Remote in Plano, TX 75023+1 location
# 506  Remote in Plano, TX 75023+1 location
# 507  Remote in Plano, TX 75023+1 location
# 508  Remote in Plano, TX 75023+1 location
# 509  Remote in Plano, TX 75023+1 location
#
#                                               job_desc      date_posted  \
# 0    The Data Scientist will be a technology leader...  Posted1 day ago
# 1    Communicate key insights from analyses, experi...  Posted1 day ago
# 2    Performs duties related to data mining, machin...  Posted1 day ago
# 3    Practical knowledge in different machine learn...  Posted1 day ago
# 4    Practical experience and strong understanding ...  Posted1 day ago
# ..                                                 ...              ...
# 505  Submit FOIA requests to obtain data and models...  Posted1 day ago
# 506  Experience with automatic machine learning (Au...  Posted1 day ago
# 507  It will also will work closely with data engin...  Posted1 day ago
# 508  Create statistically sound data sets, analysis...  Posted1 day ago
# 509  Discover actionable insights from data sources...  Posted1 day ago
#
#     date_scrapped                     salary  \
# 0      2022-05-19  $88,000 - $220,000 a year
# 1      2022-05-19  $88,000 - $220,000 a year
# 2      2022-05-19  $88,000 - $220,000 a year
# 3      2022-05-19  $88,000 - $220,000 a year
# 4      2022-05-19  $88,000 - $220,000 a year
# ..            ...                        ...
# 505    2022-05-19  $88,000 - $220,000 a year
# 506    2022-05-19  $88,000 - $220,000 a year
# 507    2022-05-19  $88,000 - $220,000 a year
# 508    2022-05-19  $88,000 - $220,000 a year
# 509    2022-05-19  $88,000 - $220,000 a year
#
#                                                job_url
# 0    https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 1    https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 2    https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 3    https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 4    https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# ..                                                 ...
# 505  https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 506  https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 507  https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 508  https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
# 509  https://www.indeed.com/rc/clk?jk=990e7165c9b5e...
#
# [510 rows x 8 columns]

# %%
remote['company'].unique()
# Out:
# array(['Toyota', 'Ford Motor Company', 'Amazon.com Services LLC', 'Yelp'],
#       dtype=object)

# %% [markdown]
# ### Indeed jobs
#
# #### data science in Dubai

# %%
https://ae.indeed.com/jobs?q=data%20scientist&l=Dubai&vjk=1f7ac72465db3e92

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://ae.indeed.com/jobs?q=data%20scientist&l=Dubai&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list3.append(jobs)
    return

# %%
job_list3 = []
c = extract(0)
transform(c)
print(len(job_list3))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,50,10):
    c = extract(0)
    transform(c)

# %%
Dubai = pd.DataFrame(job_list3)
Dubai
# Out:
#                                        title              company location  \
# 0                             Data Scientist  Affaan Technologies    Dubai
# 1    newRemuneration and Benefits Specialist  Affaan Technologies    Dubai
# 2                    newVC-SBDM-North Africa  Affaan Technologies    Dubai
# 3                               Data Analyst  Affaan Technologies    Dubai
# 4                LEAD DATA SCIENTIST - DUBAI  Affaan Technologies    Dubai
# ..                                       ...                  ...      ...
# 580                                Associate  Affaan Technologies    Dubai
# 581         newDigital Manager - IMC Manager  Affaan Technologies    Dubai
# 582    newSenior Technical Software Engineer  Affaan Technologies    Dubai
# 583                     P3 Technical Advisor  Affaan Technologies    Dubai
# 584                      Senior Data Analyst  Affaan Technologies    Dubai
#
#                                               job_desc         date_posted  \
# 0    Create algorithms to extract information from ...  Posted30+ days ago
# 1    Excellent analytical and reporting skills with...  Posted30+ days ago
# 2    While not a technical role, they should have d...  Posted30+ days ago
# 3    Data Horizon: Identify the new sources of data...  Posted30+ days ago
# 4    You will build monitoring solution of data pip...  Posted30+ days ago
# ..                                                 ...                 ...
# 580  + Accountable for a variety of complex deliver...  Posted30+ days ago
# 581  Data & analytical skill allowing you to manage...  Posted30+ days ago
# 582  Contribute to software and data engineering pl...  Posted30+ days ago
# 583  O Carrying out research and data collection.O ...  Posted30+ days ago
# 584  Data Horizon: Identify the new sources of data...  Posted30+ days ago
#
#     date_scrapped salary                                            job_url
# 0      2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 1      2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 2      2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 3      2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 4      2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# ..            ...    ...                                                ...
# 580    2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 581    2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 582    2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 583    2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
# 584    2022-05-19         https://www.indeed.com/rc/clk?jk=1f7ac72465db3...
#
# [585 rows x 8 columns]

# %%
#Dubai['company'].unique()

# %%
#Dubai['title'].unique()

# %%
#Dubai['job_url'][0]

# %% [markdown]
# ### Indeed jobs
#
# #### Abu Dhabhi
#
# #### Data scientist

# %%
https://ae.indeed.com/jobs?q=data%20scientist&l=Abu%20Dhabi&vjk=a1a29e91f88fe9dd

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://ae.indeed.com/jobs?q=data%20scientist&l=Abu%20Dhabi&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list4.append(jobs)
    return

# %%
job_list4 = []
c = extract(0)
transform(c)
print(len(job_list4))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,50,10):
    c = extract(0)
    transform(c)

# %%
Abu_Dhabhi = pd.DataFrame(job_list4)
Abu_Dhabhi
# Out:
#                                       title company   location  \
# 0   newData Scientist (Extendable Contract)  Halian  Abu Dhabi
# 1         newSenior Associate–Data Engineer  Halian  Abu Dhabi
# 2                   newData Science Manager  Halian  Abu Dhabi
# 3                          Junior Associate  Halian  Abu Dhabi
# 4                        newSystem Engineer  Halian  Abu Dhabi
# ..                                      ...     ...        ...
# 85           newProject Engineering Manager  Halian  Abu Dhabi
# 86                         Business Analyst  Halian  Abu Dhabi
# 87            newDepartment Manager Process  Halian  Abu Dhabi
# 88                newSenior Project Planner  Halian  Abu Dhabi
# 89                   newSenior I&C Engineer  Halian  Abu Dhabi
#
#                                              job_desc  date_posted  \
# 0   Ability to handle large volumes of semi-struct...  PostedToday
# 1   Strong ability to design, build and manage dat...  PostedToday
# 2   Lead and empower internal and external teams o...  PostedToday
# 3   Junior Associates join our offices and practic...  PostedToday
# 4   Fundamental AI research, through our subsidiar...  PostedToday
# ..                                                ...          ...
# 85  Builds positive working relationships with ext...  PostedToday
# 86  You'll work in teams of typically 3 - 5 consul...  PostedToday
# 87  Provides leadership to the maintenance of a sa...  PostedToday
# 88  48,000 people. 49 countries. Over 120 office l...  PostedToday
# 89  Preparation /checking of Specifications, data ...  PostedToday
#
#    date_scrapped salary                                            job_url
# 0     2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 1     2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 2     2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 3     2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 4     2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# ..           ...    ...                                                ...
# 85    2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 86    2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 87    2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 88    2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
# 89    2022-05-19         https://www.indeed.com/rc/clk?jk=a1a29e91f88fe...
#
# [90 rows x 8 columns]

# %% [markdown]
# ### UK Indeed jobs
#
# Data scientist

# %%
https://uk.indeed.com/jobs?q=data%20scientist&l=United%20Kingdom&vjk=a863223ac5385f66

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://uk.indeed.com/jobs?q=data%20scientist&l=United%20Kingdom&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list5.append(jobs)
    return

# %%
job_list5 = []
c = extract(0)
transform(c)
print(len(job_list5))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,340,10):
    c = extract(0)
    transform(c)

# %%
Uk = pd.DataFrame(job_list5)
Uk
# Out:
#                                    title        company location  \
# 0                      newData Scientist  Kindred Group   London
# 1                      newData Scientist  Kindred Group   London
# 2                         Data Scientist  Kindred Group   London
# 3                         Data Scientist  Kindred Group   London
# 4                         Data Scientist  Kindred Group   London
# ..                                   ...            ...      ...
# 520                       Data Scientist  Kindred Group   London
# 521                    newData Scientist  Kindred Group   London
# 522  newJunior Machine Learning Engineer  Kindred Group   London
# 523                       Data Scientist  Kindred Group   London
# 524                    newData Scientist  Kindred Group   London
#
#                                               job_desc  date_posted  \
# 0    We have invested heavily in data technologies ...  PostedToday
# 1    Your primary focus will be in applying data ma...  PostedToday
# 2    Strong ability using a variety of data mining ...  PostedToday
# 3    A broad understanding of data science includin...  PostedToday
# 4    In the research discipline you will help build...  PostedToday
# ..                                                 ...          ...
# 520  Strong ability using a variety of data mining ...  PostedToday
# 521  Our Data Scientists act as subject matter expe...  PostedToday
# 522  Full time / Permanent - part time & flexible w...  PostedToday
# 523  The creation of high-quality data science prod...  PostedToday
# 524  Experience in Design of Experiments, regressio...  PostedToday
#
#     date_scrapped          salary  \
# 0      2022-05-20  £50,000 a year
# 1      2022-05-20  £50,000 a year
# 2      2022-05-20  £50,000 a year
# 3      2022-05-20  £50,000 a year
# 4      2022-05-20  £50,000 a year
# ..            ...             ...
# 520    2022-05-20  £40,000 a year
# 521    2022-05-20  £40,000 a year
# 522    2022-05-20  £40,000 a year
# 523    2022-05-20  £40,000 a year
# 524    2022-05-20  £40,000 a year
#
#                                                job_url
# 0    https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 1    https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 2    https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 3    https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 4    https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# ..                                                 ...
# 520  https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 521  https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 522  https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 523  https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
# 524  https://www.indeed.com/rc/clk?jk=fc2ac2721d623...
#
# [525 rows x 8 columns]

# %% [markdown]
# ### Australia indeed jobs

# %%
https://au.indeed.com/jobs?q=data%20scientist&l=Australia&vjk=b01ea1c82cd27f65

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://au.indeed.com/jobs?q=data%20scientist&l=Australia&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list6.append(jobs)
    return

# %%
job_list6 = []
c = extract(0)
transform(c)
print(len(job_list6))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,130,10):
    c = extract(0)
    transform(c)

# %%
Australia = pd.DataFrame(job_list6)
Australia
# Out:
#                                                title  company    location  \
# 0                                  newData Scientist  Kinesso  Sydney NSW
# 1                                  newData Scientist  Kinesso  Sydney NSW
# 2                newEarth Observation Data Scientist  Kinesso  Sydney NSW
# 3                                  newData Scientist  Kinesso  Sydney NSW
# 4                Graduate Data Scientist - Melbourne  Kinesso  Sydney NSW
# ..                                               ...      ...         ...
# 205                                newData Scientist   Findex   Australia
# 206           newPhD Scholarship in Machine Learning   Findex   Australia
# 207  Data Science Intern, 2022/2023 Summer Australia   Findex   Australia
# 208                                   Data Scientist   Findex   Australia
# 209                     newSenior Data Scientist x 2   Findex   Australia
#
#                                               job_desc       date_posted  \
# 0    1+ years proven experience as a data scientist...   Posted1 day ago
# 1    Source data from multiple data sources.Analyse...   Posted1 day ago
# 2    Digital Earth Australia (DEA) delivers a uniqu...   Posted1 day ago
# 3    Assist clinical researchers in identifying dat...   Posted1 day ago
# 4    Practical experience applying data science and...   Posted1 day ago
# ..                                                 ...               ...
# 205  Good working knowledge of SQL databases includ...  Posted3 days ago
# 206  Full time, fixed term position at our Hawthorn...  Posted3 days ago
# 207  Have experience manipulating data using one of...  Posted3 days ago
# 208  Your role, alongside the other data scientists...  Posted3 days ago
# 209  This role will work as a member of a discrete ...  Posted3 days ago
#
#     date_scrapped          salary  \
# 0      2022-05-20  $85,000 a year
# 1      2022-05-20  $85,000 a year
# 2      2022-05-20  $85,000 a year
# 3      2022-05-20  $85,000 a year
# 4      2022-05-20  $85,000 a year
# ..            ...             ...
# 205    2022-05-20  $85,000 a year
# 206    2022-05-20  $85,000 a year
# 207    2022-05-20  $85,000 a year
# 208    2022-05-20  $85,000 a year
# 209    2022-05-20  $85,000 a year
#
#                                                job_url
# 0    https://www.indeed.com/rc/clk?jk=9515a6ff4291e...
# 1    https://www.indeed.com/rc/clk?jk=9515a6ff4291e...
# 2    https://www.indeed.com/rc/clk?jk=9515a6ff4291e...
# 3    https://www.indeed.com/rc/clk?jk=9515a6ff4291e...
# 4    https://www.indeed.com/rc/clk?jk=9515a6ff4291e...
# ..                                                 ...
# 205  https://www.indeed.com/rc/clk?jk=78c7cd56fe329...
# 206  https://www.indeed.com/rc/clk?jk=78c7cd56fe329...
# 207  https://www.indeed.com/rc/clk?jk=78c7cd56fe329...
# 208  https://www.indeed.com/rc/clk?jk=78c7cd56fe329...
# 209  https://www.indeed.com/rc/clk?jk=78c7cd56fe329...
#
# [210 rows x 8 columns]

# %% [markdown]
# ### Singapore Indeed

# %%
https://sg.indeed.com/jobs?q=data%20scientist&l=Singapore&vjk=0a95cba397876b01

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://sg.indeed.com/jobs?q=data%20scientist&l=Singapore&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list7.append(jobs)
    return

# %%
job_list7 = []
c = extract(0)
transform(c)
print(len(job_list7))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,330,10):
    c = extract(0)
    transform(c)

# %%
Singapore = pd.DataFrame(job_list7)
Singapore
# Out:
#                                                  title  company  \
# 0               Data Scientist Intern (Jul - Dec 2022)  Siemens
# 1    newData Science Trainee / Junior Data Analyst ...  Siemens
# 2                                    newData Scientist  Siemens
# 3                                    newData Scientist  Siemens
# 4    newData Science Trainee / Junior Data Analyst ...  Siemens
# ..                                                 ...      ...
# 505            newSenior Data Scientist (APAC, Remote)  Siemens
# 506                      Data Scientist - QuantumBlack  Siemens
# 507                newData Scientist "ML prototyping "  Siemens
# 508                                     Data Scientist  Siemens
# 509  Business Data Scientist, gTech Users and Produ...  Siemens
#
#                  location                                           job_desc  \
# 0    Singapore+1 location  Study and transform data science prototypes.Se...
# 1    Singapore+1 location  You will collect, analyze, and interpret data ...
# 2    Singapore+1 location  Experience with measuring and maintaining data...
# 3    Singapore+1 location  Utilize diverse internal and external data sou...
# 4    Singapore+1 location  You will collect, analyze, and interpret data ...
# ..                    ...                                                ...
# 505  Singapore+1 location  Influence leadership to drive more data-inform...
# 506  Singapore+1 location  You will also develop data science products an...
# 507  Singapore+1 location  Work collaboratively to architect and implemen...
# 508  Singapore+1 location  Clean up and analyse the quality of unstructur...
# 509  Singapore+1 location  Mentor analysts in other areas, data extractio...
#
#            date_posted date_scrapped                    salary  \
# 0    Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 1    Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 2    Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 3    Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 4    Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# ..                 ...           ...                       ...
# 505  Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 506  Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 507  Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 508  Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
# 509  Posted10 days ago    2022-05-20  $48,000 - $84,000 a year
#
#                                                job_url
# 0    https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 1    https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 2    https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 3    https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 4    https://www.indeed.com/rc/clk?jk=0a95cba397876...
# ..                                                 ...
# 505  https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 506  https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 507  https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 508  https://www.indeed.com/rc/clk?jk=0a95cba397876...
# 509  https://www.indeed.com/rc/clk?jk=0a95cba397876...
#
# [510 rows x 8 columns]

# %%
https://www.indeed.com/jobs?q=data%20scientist&l=Remote&

# %% [markdown]
# ### Remote indeed jobs

# %%
def extract(page):
    #check my user agent
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
    #use url from career site put page
    url = f'https://www.indeed.com/jobs?q=data%20scientist&l=Remote&start={page}'
    res = requests.get(url, headers)
    #add soup variable
    soup = BeautifulSoup(res.content, 'lxml')
    return soup

# %%
def transform(soup):
    #jobs = soup.find_all('div', class_ ='slider_item')
    jobs = soup.find_all('div', class_ ='slider_item')
    for job in jobs:
        try:
            title = job.find('h2', class_='jobTitle').get_text()
        except:
            title = 'None'
        comp = soup.find('td', class_ ='resultContent')
        company_ = comp.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        try:
            company = company_.find('span').text.strip()
        except:
            company = ''
        #try:
           # company = soup.find('span', class_ ='companyName')
        #except:
            #company = 'None'
        #try:
            #company_ = company.find('div', class_ = 'heading6 company_location tapItem-gutter companyInfo')
        #except:
            
        #co_name = company_.find('span').text.strip()
    
    #salary = soup.find('div', class_ = 'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly')
        try:
            salary = soup.find('div', 'metadata salary-snippet-container').text.strip()
        except:
            salary = ''
        try:
            location_ = soup.find('div', class_ ='companyLocation').text.strip()
        except:
            location_ = 'None'
            
        date_posted = soup.find('span', class_= 'date').text.strip()  ###
   
        desc = job.find('div', class_ = 'job-snippet').text.strip().replace('\n', '') ####
    #atag = item.find_all('a').text.strip()
        atag = soup.h2.a  ####
        
        job_url = 'https://www.indeed.com' +str(atag.get('href'))  ###
        date_collected = datetime.today().strftime('%Y-%m-%d')
#print(salary)
        jobs = {'title': title,
                'company': company,
                'location': location_,
               'job_desc': desc,
               'date_posted': date_posted,
                'date_scrapped': date_collected,
               'salary': salary,
               'job_url': job_url}
            
       
        job_list8.append(jobs)
    return

# %%
job_list8 = []
c = extract(0)
transform(c)
print(len(job_list8))
# Out:
# 15

# %%
#create a while loop to through entire web
for i in range(0,330,10):
    c = extract(0)
    transform(c)

# %%
Remote = pd.DataFrame(job_list8)
Remote
# Out:
#                                                  title  \
# 0    Data Scientist II, Workforce Staffing Market I...
# 1                              Data Scientist (Remote)
# 2                                    newData Scientist
# 3    new(Junior / Senior) Data Scientist - Sports A...
# 4                              Data Scientist (Junior)
# ..                                                 ...
# 505  new(Junior / Senior) Data Scientist - Sports A...
# 506                             newUS - Data Scientist
# 507        data scientist (multiple openings) - Remote
# 508                                     Data Scientist
# 509                                     Data Scientist
#
#                      company             location  \
# 0    Amazon.com Services LLC  +14 locationsRemote
# 1    Amazon.com Services LLC  +14 locationsRemote
# 2    Amazon.com Services LLC  +14 locationsRemote
# 3    Amazon.com Services LLC  +14 locationsRemote
# 4    Amazon.com Services LLC  +14 locationsRemote
# ..                       ...                  ...
# 505                      EAB    +1 locationRemote
# 506                      EAB    +1 locationRemote
# 507                      EAB    +1 locationRemote
# 508                      EAB    +1 locationRemote
# 509                      EAB    +1 locationRemote
#
#                                               job_desc         date_posted  \
# 0    You will collaborate closely as part of a blen...  Posted30+ days ago
# 1    Communicate key insights from analyses, experi...  Posted30+ days ago
# 2    Design, validate, and visualize data-driven mo...  Posted30+ days ago
# 3    Provide guidance and technical mentorship for ...  Posted30+ days ago
# 4    For example, combining public weather data wit...  Posted30+ days ago
# ..                                                 ...                 ...
# 505  Provide guidance and technical mentorship for ...    Posted3 days ago
# 506  They focus in applying machine learning techni...    Posted3 days ago
# 507  Experience building complex data sets from mul...    Posted3 days ago
# 508  Experience with automatic machine learning (Au...    Posted3 days ago
# 509  Performs duties related to data mining, machin...    Posted3 days ago
#
#     date_scrapped                      salary  \
# 0      2022-05-20  $119,300 - $160,000 a year
# 1      2022-05-20  $119,300 - $160,000 a year
# 2      2022-05-20  $119,300 - $160,000 a year
# 3      2022-05-20  $119,300 - $160,000 a year
# 4      2022-05-20  $119,300 - $160,000 a year
# ..            ...                         ...
# 505    2022-05-20   $88,000 - $220,000 a year
# 506    2022-05-20   $88,000 - $220,000 a year
# 507    2022-05-20   $88,000 - $220,000 a year
# 508    2022-05-20   $88,000 - $220,000 a year
# 509    2022-05-20   $88,000 - $220,000 a year
#
#                                                job_url
# 0    https://www.indeed.com/rc/clk?jk=c60f37dae36c8...
# 1    https://www.indeed.com/rc/clk?jk=c60f37dae36c8...
# 2    https://www.indeed.com/rc/clk?jk=c60f37dae36c8...
# 3    https://www.indeed.com/rc/clk?jk=c60f37dae36c8...
# 4    https://www.indeed.com/rc/clk?jk=c60f37dae36c8...
# ..                                                 ...
# 505  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 506  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 507  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 508  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 509  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
#
# [510 rows x 8 columns]

# %%
ind_df = pd.concat([test, remote,Dubai,Abu_Dhabhi,Uk,Australia,Singapore,Remote])

# %%
ind_df.to_csv('indeed_jobs.csv')

# %%
ind_df.shape
# Out:
# (3930, 8)
