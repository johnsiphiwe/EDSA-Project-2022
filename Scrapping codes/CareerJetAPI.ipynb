# %% [markdown]
# # Careerjet API

# %% [markdown]
# Careerjet is a job search engine that pulls job postings from company and organization websites in a variety of industries and locations. Users searching for employment may also post their resume on Careerjet, as well as create job alerts.

# %% [markdown]
# ## Importing Packages

# %%
# import libraries
from careerjet_api import CareerjetAPIClient
import requests
import pandas as pd
import time

# %% [markdown]
# ## Extracting Jobs In South Africa with a key Words (Data sciencetist, Data Analyst, Machine learning, Power BI, SQL...)

# %% [markdown]
# * ### Machine learning Jobs

# %%
cj_1  =  CareerjetAPIClient("en_ZA");

result_json_1 = cj_1.search({
                        'location'    : 'South Africa',
                        'keywords'    : 'machine learning',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.za/search/jobs?s=data+science&l=South+Africa&lid=37483&radius=0',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
result_json_1
# Out:
# {'jobs': [{'locations': 'Stellenbosch, Western Cape - Cape Town, Western Cape',
#    'site': '',
#    'date': 'Sun, 01 May 2022 06:53:08 GMT',
#    'url': 'http://jobviewtrack.com/en-za/job-1f4841604c0707074911002f0d001c090c4e13482c1d4d42534848166d3d5e07540605124e220b471d060c165829704c4e0c060042546c060913000e0b47762d0714434558485f44220f441c490d0d63220204521a0107140a78445e5901021d264612525f575f655712455f5047/e63e781749ace926cc9f1b4c6fffe18b.html?affid=3943ce450790cc9c0eea91620540ef82',
#    'title': 'Machine Learning Engineer (Recommendation Systems)',
#    'description': "Takealot.com, South Africa's leading online retailer, is looking for a highly talented <b>Machine</b> <b>Learning</b> Engineer... reports to the respective Engineering Manager for that team.   We are looking for an experienced <b>Machine</b> <b>Learning</b> Engineer...",
#    'company': 'Takealot',
#    'salary': ''},
#   {'locations': 'Johannesburg, Gauteng',
#    'site': '',
# ...

# %%
ML_Jobs = result_json_1["jobs"]

# %%
ML_Jobs
# Out:
# [{'locations': 'Stellenbosch, Western Cape - Cape Town, Western Cape',
#   'site': '',
#   'date': 'Sun, 01 May 2022 06:53:08 GMT',
#   'url': 'http://jobviewtrack.com/en-za/job-1f4841604c0707074911002f0d001c090c4e13482c1d4d42534848166d3d5e07540605124e220b471d060c165829704c4e0c060042546c060913000e0b47762d0714434558485f44220f441c490d0d63220204521a0107140a78445e5901021d264612525f575f655712455f5047/e63e781749ace926cc9f1b4c6fffe18b.html?affid=3943ce450790cc9c0eea91620540ef82',
#   'title': 'Machine Learning Engineer (Recommendation Systems)',
#   'description': "Takealot.com, South Africa's leading online retailer, is looking for a highly talented <b>Machine</b> <b>Learning</b> Engineer... reports to the respective Engineering Manager for that team.   We are looking for an experienced <b>Machine</b> <b>Learning</b> Engineer...",
#   'company': 'Takealot',
#   'salary': ''},
#  {'locations': 'Johannesburg, Gauteng',
#   'site': '',
#   'date': 'Tue, 26 Apr 2022 22:24:43 GMT',
# ...

# %%
df = pd.DataFrame(ML_Jobs )

# %%
df.columns
# Out:
# Index(['locations', 'site', 'date', 'url', 'title', 'description', 'company',
#        'salary', 'salary_min', 'salary_type', 'salary_currency_code',
#        'salary_max'],
#       dtype='object')

# %%
ML_Jobs_SA = df.loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %%
ML_Jobs_SA
# Out:
#                         company  \
# 0                      Takealot
# 1        e-Merge IT Recruitment
# 2
# 3                  Be Different
# 4               The Focus Group
# 5      M-Ploy Global Resourcing
# 6      Talent Advance (Pty) Ltd
# 7      Be Different Recruitment
# 8                      Takealot
# 9                     PBT Group
# 10       e-Merge IT Recruitment
# 11       e-Merge IT Recruitment
# 12       e-Merge IT Recruitment
# 13                      Tumaini
# 14      Communicate Recruitment
# 15  Communicate Central Finance
# 16      Communicate Recruitment
# 17                    InstaDeep
# 18                     Prostaff
# 19      Communicate Recruitment
#
#                                                 title  \
# 0   Machine Learning Engineer (Recommendation Syst...
# 1                               Machine Learning Guru
# 2                    Senior Machine Learning Engineer
# 3   AWS Cloud and Machine Learning – Software Engi...
# ...

# %% [markdown]
# * ### Data analyst Jobs

# %%
cj_2  =  CareerjetAPIClient("en_ZA");

result_json_2 = cj_2.search({
                        'location'    : 'South Africa',
                        'keywords'    : 'data analyst',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.za/search/jobs?s=data+science&l=South+Africa&lid=37483&radius=0',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
DA_Jobs = result_json_2["jobs"]

# %%
DA_df = pd.DataFrame(DS_Jobs)

# %%
DA_Jobs_SA = DS_df.loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %% [markdown]
# * ### Data Scientist Jobs

# %%
cj_3  =  CareerjetAPIClient("en_ZA");

result_json_3 = cj_3.search({
                        'location'    : 'South Africa',
                        'keywords'    : 'Data scientist',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.za/search/jobs?s=data+science&l=South+Africa&lid=37483&radius=0',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
DS_Jobs = result_json_3["jobs"]

# %%
DS_df = pd.DataFrame(DS_Jobs)

# %%
DS_Jobs_SA = DS_df.loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %%
# concat dataframes
SA_Jobs = pd.concat([ML_Jobs_SA, DA_Jobs_SA,DS_Jobs_SA], axis=0, ignore_index=True)

# %%
SA_Jobs
# Out:
#                                   company  \
# 0                                Takealot
# 1                  e-Merge IT Recruitment
# 2
# 3                            Be Different
# 4                         The Focus Group
# 5                M-Ploy Global Resourcing
# 6                Talent Advance (Pty) Ltd
# 7                Be Different Recruitment
# 8                                Takealot
# 9                               PBT Group
# 10                 e-Merge IT Recruitment
# 11                 e-Merge IT Recruitment
# 12                 e-Merge IT Recruitment
# 13                                Tumaini
# 14                Communicate Recruitment
# 15            Communicate Central Finance
# 16                Communicate Recruitment
# 17                              InstaDeep
# 18                               Prostaff
# 19                Communicate Recruitment
# 20                      Afrizan Personnel
# 21         Cora O'Neil Recruitment Agency
# 22
# ...

# %% [markdown]
# ## Extracting Jobs In United Kingdom with a key Words (Data sciencetist, Data Analyst, Machine learning, Power BI, SQL...)

# %% [markdown]
# * ### Machine learning

# %%
cj_4  =  CareerjetAPIClient("en_GB");

result_json_4 = cj_4.search({
                        'location'    : 'United Kingdom',
                        'keywords'    : 'machine learning',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.uk/search/jobs?s=data+science&l=United+Kingdom',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
UKML = result_json_4["jobs"]

# %%
ML_UK = pd.DataFrame(UKML)

# %%
ML_Jobs_UK = ML_UK .loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %% [markdown]
# * ### Data Analyst

# %%
cj_5  =  CareerjetAPIClient("en_GB");

result_json_5 = cj_5.search({
                        'location'    : 'United Kingdom',
                        'keywords'    : 'data analyst',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.uk/search/jobs?s=data+science&l=United+Kingdom',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
UKDA = result_json_4["jobs"]

# %%
DA_UK = pd.DataFrame(UKDA)

# %%
DA_Jobs_UK = DA_UK .loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %% [markdown]
# * ### Data Scientist

# %%
cj_6  =  CareerjetAPIClient("en_GB");

result_json_6 = cj_6.search({
                        'location'    : 'United Kingdom',
                        'keywords'    : 'data scientist',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.uk/search/jobs?s=data+science&l=United+Kingdom',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
UKDS = result_json_4["jobs"]

# %%
DS_UK = pd.DataFrame(UKDS)

# %%
DS_Jobs_UK = DS_UK .loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %%
# concat dataframes
UK_Jobs = pd.concat([ML_Jobs_UK, DA_Jobs_UK,DS_Jobs_UK], axis=0, ignore_index=True)

# %% [markdown]
# # Extracting Jobs In India with a key Words (Data sciencetist, Data Analyst, Machine learning, Power BI, SQL...)

# %% [markdown]
# * ### Machine learning

# %%
cj_7  =  CareerjetAPIClient("en_IN");

result_json_7 = cj_7.search({
                        'location'    : 'India',
                        'keywords'    : 'Machine learning',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.in/search/jobs?s=data+science&l=India',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
INDS = result_json_4["jobs"]

# %%
ML_IN = pd.DataFrame(INDS)

# %%
ML_Jobs_IN = ML_IN .loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %% [markdown]
# * ### Data Analyst

# %%
cj_8  =  CareerjetAPIClient("en_IN");

result_json_8 = cj_8.search({
                        'location'    : 'India',
                        'keywords'    : 'Data analyst',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.in/search/jobs?s=data+science&l=India',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
INDA = result_json_4["jobs"]

# %%
DA_IN = pd.DataFrame(INDA)

# %%
DA_Jobs_IN = DA_IN .loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %% [markdown]
# * ### Data scietist

# %%
cj_9  =  CareerjetAPIClient("en_IN");

result_json_9 = cj_9.search({
                        'location'    : 'India',
                        'keywords'    : 'Data scientist',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.in/search/jobs?s=data+science&l=India',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
INDS = result_json_4["jobs"]

# %%
DS_IN = pd.DataFrame(INDS)

# %%
DS_Jobs_IN = DS_IN .loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %%
# concat dataframes
IN_Jobs = pd.concat([ML_Jobs_IN, DA_Jobs_IN,DS_Jobs_IN], axis=0, ignore_index=True)

# %% [markdown]
# ## Combining the dataframes

# %%
# concat dataframes
Jobs = pd.concat([SA_Jobs, UK_Jobs,IN_Jobs], axis=0, ignore_index=True)

# %%
Jobs.shape
# Out:
# (180, 12)

# %%
Jobs
# Out:
#                          company  \
# 0                       Takealot
# 1         e-Merge IT Recruitment
# 2
# 3                   Be Different
# 4                The Focus Group
# ..                           ...
# 175                     Sentinel
# 176               Project People
# 177                          CGG
# 178  Edinburgh Napier University
# 179                     DeepMind
#
#                                                  title  \
# 0    Machine Learning Engineer (Recommendation Syst...
# 1                                Machine Learning Guru
# 2                     Senior Machine Learning Engineer
# 3    AWS Cloud and Machine Learning – Software Engi...
# 4                      Machine learning Ops Specialist
# ..                                                 ...
# 175                          Machine Learning Engineer
# 176          Machine Learning Engineer - Search Engine
# 177  Machine Learning Engineer/ Researcher - 2022 P...
# ...

# %%
keywords = ['Data sciencetist', 'Data Analyst', 'Machine learning', 'Power BI', 'SQL']

for key in keywords:
    cj  =  CareerjetAPIClient("en_ZA");

    result_json = cj.search({
                        'location'    : 'South Africa',
                        'keywords'    : key,
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.za/search/jobs?s=data+science&l=South+Africa&lid=37483&radius=0',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });
    with open(key + '.json', 'w') as outfile:
        json.dump(result_json, outfile)

# %%
from careerjet_api_client import CareerjetAPIClient
import time, json
from config import affid, user_ip, url

cj  =  CareerjetAPIClient("en_GB");

locations = ['africa', 'asia', 'australia', 'europe', 'north america', 'south america']

for loc in locations:
    result_json = cj.search({
                            'location'    : loc,
                            'keywords'    : 'data scientist',
                            'sort'        : 'salary',
                            'affid'       : affid,
                            'user_ip'     : user_ip,
                            'url'         : url,
                            'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                            });
    
    with open(loc + '.json', 'w') as outfile:
        json.dump(result_json, outfile)
    
    time.sleep(20)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Tshegofatso\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-126-fb2d16be1fff>", line 1, in <module>
#     from careerjet_api_client import CareerjetAPIClient
#
#   File "C:\Users\Tshegofatso\anaconda3\lib\site-packages\careerjet_api_client\__init__.py", line 114
#     except Exception, e:
#                     ^
# SyntaxError: invalid syntax
