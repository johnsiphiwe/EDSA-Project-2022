# %% [markdown]
# ## Importing Packages

# %%
# import libraries
from careerjet_api import CareerjetAPIClient
import requests
import pandas as pd
import time

# %% [markdown]
# ## Extracting Jobs In South Africa with a key Words (Data science, Machine learning, Power BI, SQL)

# %%
cj_1  =  CareerjetAPIClient("en_ZA");

result_json_1 = cj_1.search({
                        'location'    : 'South Africa',
                        'keywords'    : 'machine learning',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.za/search/jobs?s=data+science&l=South+Africa&lid=37483&radius=0',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
result_json_1
# Out:
# {'jobs': [{'locations': 'Stellenbosch, Western Cape - Cape Town, Western Cape',
#    'site': '',
#    'date': 'Sun, 01 May 2022 06:53:08 GMT',
#    'url': 'http://jobviewtrack.com/en-za/job-1f4841604c0707074911002f0d001c090c4e13482c1d4d42534848166d3d5e07540605124e220b471d060c165829704c4e0c060042546c060913000e0b47762d0714434558485f44220f441c490d0d63220204521a0107140a78445e5901021d264612525f575f655712455f5047/e63e781749ace926cc9f1b4c6fffe18b.html?affid=3943ce450790cc9c0eea91620540ef82',
#    'title': 'Machine Learning Engineer (Recommendation Systems)',
#    'description': "Takealot.com, South Africa's leading online retailer, is looking for a highly talented <b>Machine</b> <b>Learning</b> Engineer... reports to the respective Engineering Manager for that team.   We are looking for an experienced <b>Machine</b> <b>Learning</b> Engineer...",
#    'company': 'Takealot',
#    'salary': ''},
#   {'locations': 'Johannesburg, Gauteng',
#    'site': '',
# ...

# %%
ML_Jobs = result_json_1["jobs"]

# %%
ML_Jobs
# Out:
# [{'locations': 'Stellenbosch, Western Cape - Cape Town, Western Cape',
#   'site': '',
#   'date': 'Sun, 01 May 2022 06:53:08 GMT',
#   'url': 'http://jobviewtrack.com/en-za/job-1f4841604c0707074911002f0d001c090c4e13482c1d4d42534848166d3d5e07540605124e220b471d060c165829704c4e0c060042546c060913000e0b47762d0714434558485f44220f441c490d0d63220204521a0107140a78445e5901021d264612525f575f655712455f5047/e63e781749ace926cc9f1b4c6fffe18b.html?affid=3943ce450790cc9c0eea91620540ef82',
#   'title': 'Machine Learning Engineer (Recommendation Systems)',
#   'description': "Takealot.com, South Africa's leading online retailer, is looking for a highly talented <b>Machine</b> <b>Learning</b> Engineer... reports to the respective Engineering Manager for that team.   We are looking for an experienced <b>Machine</b> <b>Learning</b> Engineer...",
#   'company': 'Takealot',
#   'salary': ''},
#  {'locations': 'Johannesburg, Gauteng',
#   'site': '',
#   'date': 'Tue, 26 Apr 2022 22:24:43 GMT',
# ...

# %%
df = pd.DataFrame(ML_Jobs )

# %%
df.columns
# Out:
# Index(['locations', 'site', 'date', 'url', 'title', 'description', 'company',
#        'salary', 'salary_min', 'salary_type', 'salary_currency_code',
#        'salary_max'],
#       dtype='object')

# %%
ML_Jobs_SA = df.loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %%
ML_Jobs_SA
# Out:
#                         company  \
# 0                      Takealot
# 1        e-Merge IT Recruitment
# 2
# 3                  Be Different
# 4               The Focus Group
# 5      M-Ploy Global Resourcing
# 6      Talent Advance (Pty) Ltd
# 7      Be Different Recruitment
# 8                      Takealot
# 9                     PBT Group
# 10       e-Merge IT Recruitment
# 11       e-Merge IT Recruitment
# 12       e-Merge IT Recruitment
# 13                      Tumaini
# 14      Communicate Recruitment
# 15  Communicate Central Finance
# 16      Communicate Recruitment
# 17                    InstaDeep
# 18                     Prostaff
# 19      Communicate Recruitment
#
#                                                 title  \
# 0   Machine Learning Engineer (Recommendation Syst...
# 1                               Machine Learning Guru
# 2                    Senior Machine Learning Engineer
# 3   AWS Cloud and Machine Learning – Software Engi...
# ...

# %%
cj_2  =  CareerjetAPIClient("en_ZA");

result_json_2 = cj_1.search({
                        'location'    : 'South Africa',
                        'keywords'    : 'data science',
                        'affid'       : '3943ce450790cc9c0eea91620540ef82',
                        'user_ip'     : '41.13.92.164',
                        'url'         : 'https://www.careerjet.co.za/search/jobs?s=data+science&l=South+Africa&lid=37483&radius=0',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
DS_Jobs = result_json_2["jobs"]

# %%
DS_df = pd.DataFrame(DS_Jobs)

# %%
DS_Jobs_SA = DS_df.loc[:, ['company','title','locations','description','date', 'url', 'site','salary_currency_code', 'salary', 'salary_type', 'salary_min', 'salary_max',]]

# %%
DS_Jobs_SA
# Out:
#                     company  \
# 0                    Google
# 1             Standard Bank
# 2    e-Merge IT Recruitment
# 3                TransUnion
# 4         iSanqa Resourcing
# 5    Mass Staffing Projects
# 6           The Focus Group
# 7   JTJ Recruitment Support
# 8    e-Merge IT Recruitment
# 9               Key Careers
# 10   Mass Staffing Projects
# 11           ASAP Resources
# 12     Ntirho Human Capital
# 13     Ntirho Human Capital
# 14             Capitec Bank
# 15                HR Studio
# 16                  Immploy
# 17               IHS Markit
# 18      Enshrine Placements
# 19  Communicate Recruitment
#
#                                                 title  \
# 0                     Data Analytics Sales Specialist
# 1               Manager, Data and Behavioural Science
# 2   AWS Data Science Architect – Semi Remote – R74...
# 3              Consultant, Data Science and Analytics
# 4   AWS Data Science Architect (Contract) Midrand/...
# ...
