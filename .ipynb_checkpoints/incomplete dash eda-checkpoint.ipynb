# %%
import glob
import pandas as pd
from datetime import datetime, timedelta

# %%
cd C:\Users\sjtsi\Documents\Intern project\dashboard2
# Out:
# C:\Users\sjtsi\Documents\Intern project\dashboard2

# %%
joblisting = pd.concat(map(pd.read_csv, ['career_jet_df.csv', 'Global_Markets.csv', 'indeed_jobs.csv']))

# %%
joblisting
# Out:
#       Unnamed: 0                                              title  \
# 0              0  AWS Data Science Architect (QlikView & QlikSen...
# 1              1  Business Intelligence Developer (with Cloud an...
# 2              2                               Data science manager
# 3              3                               Data science manager
# 4              4  Business Intelligence Developer (with Cloud an...
# ...          ...                                                ...
# 3925         505  new(Junior / Senior) Data Scientist - Sports A...
# 3926         506                             newUS - Data Scientist
# 3927         507        data scientist (multiple openings) - Remote
# 3928         508                                     Data Scientist
# 3929         509                                     Data Scientist
#
#                       company               location  \
# 0           iSanqa Resourcing  Midrand, Johannesburg
# 1      e-Merge IT Recruitment  Johannesburg, Gauteng
# 2     Communicate Recruitment  Johannesburg, Gauteng
# 3     Communicate Recruitment  Johannesburg, Gauteng
# 4      e-Merge IT Recruitment  Johannesburg, Gauteng
# ...                       ...                    ...
# 3925                      EAB      +1 locationRemote
# 3926                      EAB      +1 locationRemote
# 3927                      EAB      +1 locationRemote
# 3928                      EAB      +1 locationRemote
# 3929                      EAB      +1 locationRemote
#
#                                                job_desc       date_posted  \
# 0     AWS Data Science Architect (QlikView & QlikSen...              None
# 1     An awesome opportunity is available for a Busi...        2 days ago
# 2     *Reference: CPM008305-THa-2*   Our client in f...        3 days ago
# 3     *Reference: CPM008305-RMo-1*   Our client in f...        3 days ago
# 4     An awesome opportunity is available for a Busi...        3 days ago
# ...                                                 ...               ...
# 3925  Provide guidance and technical mentorship for ...  Posted3 days ago
# 3926  They focus in applying machine learning techni...  Posted3 days ago
# 3927  Experience building complex data sets from mul...  Posted3 days ago
# 3928  Experience with automatic machine learning (Au...  Posted3 days ago
# 3929  Performs duties related to data mining, machin...  Posted3 days ago
#
#      date_scrapped                     salary  \
# 0       2022-05-08                        NaN
# 1       2022-05-08                        NaN
# 2       2022-05-08  R620,000-700,000 per year
# 3       2022-05-08  R620,000-700,000 per year
# 4       2022-05-08                        NaN
# ...            ...                        ...
# 3925    2022-05-20  $88,000 - $220,000 a year
# 3926    2022-05-20  $88,000 - $220,000 a year
# 3927    2022-05-20  $88,000 - $220,000 a year
# 3928    2022-05-20  $88,000 - $220,000 a year
# 3929    2022-05-20  $88,000 - $220,000 a year
#
#                                                 job_url
# 0     https://www.careerjet.co.za/jobad/zae5921d3d4a...
# 1     https://www.careerjet.co.za/jobad/zadbe4ba70e8...
# 2     https://www.careerjet.co.za/jobad/zae0c9b80b17...
# 3     https://www.careerjet.co.za/jobad/zab3ed08a036...
# 4     https://www.careerjet.co.za/jobad/za589075d2ad...
# ...                                                 ...
# 3925  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3926  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3927  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3928  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3929  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
#
# [8930 rows x 9 columns]

# %%
#remove duplicates
joblisting.drop_duplicates()
#joblisting.shape
# Out:
#       Unnamed: 0                                              title  \
# 0              0  AWS Data Science Architect (QlikView & QlikSen...
# 1              1  Business Intelligence Developer (with Cloud an...
# 2              2                               Data science manager
# 3              3                               Data science manager
# 4              4  Business Intelligence Developer (with Cloud an...
# ...          ...                                                ...
# 3925         505  new(Junior / Senior) Data Scientist - Sports A...
# 3926         506                             newUS - Data Scientist
# 3927         507        data scientist (multiple openings) - Remote
# 3928         508                                     Data Scientist
# 3929         509                                     Data Scientist
#
#                       company               location  \
# 0           iSanqa Resourcing  Midrand, Johannesburg
# 1      e-Merge IT Recruitment  Johannesburg, Gauteng
# 2     Communicate Recruitment  Johannesburg, Gauteng
# 3     Communicate Recruitment  Johannesburg, Gauteng
# 4      e-Merge IT Recruitment  Johannesburg, Gauteng
# ...                       ...                    ...
# 3925                      EAB      +1 locationRemote
# 3926                      EAB      +1 locationRemote
# 3927                      EAB      +1 locationRemote
# 3928                      EAB      +1 locationRemote
# 3929                      EAB      +1 locationRemote
#
#                                                job_desc       date_posted  \
# 0     AWS Data Science Architect (QlikView & QlikSen...              None
# 1     An awesome opportunity is available for a Busi...        2 days ago
# 2     *Reference: CPM008305-THa-2*   Our client in f...        3 days ago
# 3     *Reference: CPM008305-RMo-1*   Our client in f...        3 days ago
# 4     An awesome opportunity is available for a Busi...        3 days ago
# ...                                                 ...               ...
# 3925  Provide guidance and technical mentorship for ...  Posted3 days ago
# 3926  They focus in applying machine learning techni...  Posted3 days ago
# 3927  Experience building complex data sets from mul...  Posted3 days ago
# 3928  Experience with automatic machine learning (Au...  Posted3 days ago
# 3929  Performs duties related to data mining, machin...  Posted3 days ago
#
#      date_scrapped                     salary  \
# 0       2022-05-08                        NaN
# 1       2022-05-08                        NaN
# 2       2022-05-08  R620,000-700,000 per year
# 3       2022-05-08  R620,000-700,000 per year
# 4       2022-05-08                        NaN
# ...            ...                        ...
# 3925    2022-05-20  $88,000 - $220,000 a year
# 3926    2022-05-20  $88,000 - $220,000 a year
# 3927    2022-05-20  $88,000 - $220,000 a year
# 3928    2022-05-20  $88,000 - $220,000 a year
# 3929    2022-05-20  $88,000 - $220,000 a year
#
#                                                 job_url
# 0     https://www.careerjet.co.za/jobad/zae5921d3d4a...
# 1     https://www.careerjet.co.za/jobad/zadbe4ba70e8...
# 2     https://www.careerjet.co.za/jobad/zae0c9b80b17...
# 3     https://www.careerjet.co.za/jobad/zab3ed08a036...
# 4     https://www.careerjet.co.za/jobad/za589075d2ad...
# ...                                                 ...
# 3925  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3926  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3927  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3928  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
# 3929  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...
#
# [8834 rows x 9 columns]

# %%
#create experience feature

def experience(x):
   
    junior = ['internship', 'junior', 'graduate']
    mid_level= ['3 years', '4 years', 'exceptional', 'experience']
    senior = ['sr', 'manager', '6 year', '10 years', 'lead']
    
    for word in x.lower().split():
        if word in junior:
            return 'Junior'
        elif word in senior:
            return 'Senior'
        elif word in mid_level:
            return 'Mid_level 3-5 years'
        else:
            return 'Mid_level 1-2 years'

# %%
joblisting['experience'] = joblisting['job_desc'].map(experience)

# %%
#remove alphabets
joblisting['number_days'] = joblisting['date_posted'].str.extract('(\d+)', expand=False)

# %%
joblisting['date_scrapped'] = pd.to_datetime(joblisting['date_scrapped'])

# %%
#convert number days to date and minus
joblisting['number_days'] = joblisting['number_days'].fillna(0).astype(int)
joblisting['number_days']
# Out:
# 0       0
# 1       2
# 2       3
# 3       3
# 4       3
#        ..
# 3925    3
# 3926    3
# 3927    3
# 3928    3
# 3929    3
# Name: number_days, Length: 8930, dtype: int32

# %%
joblisting['date2'] = joblisting['date_scrapped'] -  pd.to_timedelta(joblisting['number_days'], unit = 'd')
joblisting['date2']
# Out:
# 0      2022-05-08
# 1      2022-05-06
# 2      2022-05-05
# 3      2022-05-05
# 4      2022-05-05
#           ...
# 3925   2022-05-17
# 3926   2022-05-17
# 3927   2022-05-17
# 3928   2022-05-17
# 3929   2022-05-17
# Name: date2, Length: 8930, dtype: datetime64[ns]

# %%
joblisting
# Out:
#       Unnamed: 0                                              title  \
# 0              0  AWS Data Science Architect (QlikView & QlikSen...
# 1              1  Business Intelligence Developer (with Cloud an...
# 2              2                               Data science manager
# 3              3                               Data science manager
# 4              4  Business Intelligence Developer (with Cloud an...
# ...          ...                                                ...
# 3925         505  new(Junior / Senior) Data Scientist - Sports A...
# 3926         506                             newUS - Data Scientist
# 3927         507        data scientist (multiple openings) - Remote
# 3928         508                                     Data Scientist
# 3929         509                                     Data Scientist
#
#                       company               location  \
# 0           iSanqa Resourcing  Midrand, Johannesburg
# 1      e-Merge IT Recruitment  Johannesburg, Gauteng
# 2     Communicate Recruitment  Johannesburg, Gauteng
# 3     Communicate Recruitment  Johannesburg, Gauteng
# 4      e-Merge IT Recruitment  Johannesburg, Gauteng
# ...                       ...                    ...
# 3925                      EAB      +1 locationRemote
# 3926                      EAB      +1 locationRemote
# 3927                      EAB      +1 locationRemote
# 3928                      EAB      +1 locationRemote
# 3929                      EAB      +1 locationRemote
#
#                                                job_desc       date_posted  \
# 0     AWS Data Science Architect (QlikView & QlikSen...              None
# 1     An awesome opportunity is available for a Busi...        2 days ago
# 2     *Reference: CPM008305-THa-2*   Our client in f...        3 days ago
# 3     *Reference: CPM008305-RMo-1*   Our client in f...        3 days ago
# 4     An awesome opportunity is available for a Busi...        3 days ago
# ...                                                 ...               ...
# 3925  Provide guidance and technical mentorship for ...  Posted3 days ago
# 3926  They focus in applying machine learning techni...  Posted3 days ago
# 3927  Experience building complex data sets from mul...  Posted3 days ago
# 3928  Experience with automatic machine learning (Au...  Posted3 days ago
# 3929  Performs duties related to data mining, machin...  Posted3 days ago
#
#      date_scrapped                     salary  \
# 0       2022-05-08                        NaN
# 1       2022-05-08                        NaN
# 2       2022-05-08  R620,000-700,000 per year
# 3       2022-05-08  R620,000-700,000 per year
# 4       2022-05-08                        NaN
# ...            ...                        ...
# 3925    2022-05-20  $88,000 - $220,000 a year
# 3926    2022-05-20  $88,000 - $220,000 a year
# 3927    2022-05-20  $88,000 - $220,000 a year
# 3928    2022-05-20  $88,000 - $220,000 a year
# 3929    2022-05-20  $88,000 - $220,000 a year
#
#                                                 job_url           experience  \
# 0     https://www.careerjet.co.za/jobad/zae5921d3d4a...  Mid_level 1-2 years
# 1     https://www.careerjet.co.za/jobad/zadbe4ba70e8...  Mid_level 1-2 years
# 2     https://www.careerjet.co.za/jobad/zae0c9b80b17...  Mid_level 1-2 years
# 3     https://www.careerjet.co.za/jobad/zab3ed08a036...  Mid_level 1-2 years
# 4     https://www.careerjet.co.za/jobad/za589075d2ad...  Mid_level 1-2 years
# ...                                                 ...                  ...
# 3925  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 1-2 years
# 3926  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 1-2 years
# 3927  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 3-5 years
# 3928  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 3-5 years
# 3929  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 1-2 years
#
#       number_days      date2
# 0               0 2022-05-08
# 1               2 2022-05-06
# 2               3 2022-05-05
# 3               3 2022-05-05
# 4               3 2022-05-05
# ...           ...        ...
# 3925            3 2022-05-17
# 3926            3 2022-05-17
# 3927            3 2022-05-17
# 3928            3 2022-05-17
# 3929            3 2022-05-17
#
# [8930 rows x 12 columns]

# %%
joblisting['title']

# %%
#fix title

def fix_title(x):
    
    machine_learning = ['machine', 'learning']
    data_scientist = ['data','scientist', 'science']
    bus_intel = ['business', 'intelligence', 'developer']
    data_analyst = ['data', 'analyst',]
    aws = ['aws', 'data', 'science', 'architect']
    data_engineer = ['engineer', 'engineering']
    software = ['software']
    
    for word in x.lower().split():
        if word in machine_learning:
            return 'Machine Learning'
        elif word in data_scientist:
            return 'Data scientist'
        elif word in bus_intel:
            return 'Business Intelligence'
        elif word in aws:
            return 'AWS Data Science Architect'
        elif word in data_analyst:
            return 'Data analyst'
        elif word in data_engineer:
            return 'Data engineer'
        elif word in software:
            return 'Software Developer'
        else:
            return 'Data Science'

# %%
joblisting['summary_title']= joblisting['job_desc'].apply(fix_title)

# %%
joblisting
# Out:
#       Unnamed: 0                                              title  \
# 0              0  AWS Data Science Architect (QlikView & QlikSen...
# 1              1  Business Intelligence Developer (with Cloud an...
# 2              2                               Data science manager
# 3              3                               Data science manager
# 4              4  Business Intelligence Developer (with Cloud an...
# ...          ...                                                ...
# 3925         505  new(Junior / Senior) Data Scientist - Sports A...
# 3926         506                             newUS - Data Scientist
# 3927         507        data scientist (multiple openings) - Remote
# 3928         508                                     Data Scientist
# 3929         509                                     Data Scientist
#
#                       company               location  \
# 0           iSanqa Resourcing  Midrand, Johannesburg
# 1      e-Merge IT Recruitment  Johannesburg, Gauteng
# 2     Communicate Recruitment  Johannesburg, Gauteng
# 3     Communicate Recruitment  Johannesburg, Gauteng
# 4      e-Merge IT Recruitment  Johannesburg, Gauteng
# ...                       ...                    ...
# 3925                      EAB      +1 locationRemote
# 3926                      EAB      +1 locationRemote
# 3927                      EAB      +1 locationRemote
# 3928                      EAB      +1 locationRemote
# 3929                      EAB      +1 locationRemote
#
#                                                job_desc       date_posted  \
# 0     AWS Data Science Architect (QlikView & QlikSen...              None
# 1     An awesome opportunity is available for a Busi...        2 days ago
# 2     *Reference: CPM008305-THa-2*   Our client in f...        3 days ago
# 3     *Reference: CPM008305-RMo-1*   Our client in f...        3 days ago
# 4     An awesome opportunity is available for a Busi...        3 days ago
# ...                                                 ...               ...
# 3925  Provide guidance and technical mentorship for ...  Posted3 days ago
# 3926  They focus in applying machine learning techni...  Posted3 days ago
# 3927  Experience building complex data sets from mul...  Posted3 days ago
# 3928  Experience with automatic machine learning (Au...  Posted3 days ago
# 3929  Performs duties related to data mining, machin...  Posted3 days ago
#
#      date_scrapped                     salary  \
# 0       2022-05-08                        NaN
# 1       2022-05-08                        NaN
# 2       2022-05-08  R620,000-700,000 per year
# 3       2022-05-08  R620,000-700,000 per year
# 4       2022-05-08                        NaN
# ...            ...                        ...
# 3925    2022-05-20  $88,000 - $220,000 a year
# 3926    2022-05-20  $88,000 - $220,000 a year
# 3927    2022-05-20  $88,000 - $220,000 a year
# 3928    2022-05-20  $88,000 - $220,000 a year
# 3929    2022-05-20  $88,000 - $220,000 a year
#
#                                                 job_url           experience  \
# 0     https://www.careerjet.co.za/jobad/zae5921d3d4a...  Mid_level 1-2 years
# 1     https://www.careerjet.co.za/jobad/zadbe4ba70e8...  Mid_level 1-2 years
# 2     https://www.careerjet.co.za/jobad/zae0c9b80b17...  Mid_level 1-2 years
# 3     https://www.careerjet.co.za/jobad/zab3ed08a036...  Mid_level 1-2 years
# 4     https://www.careerjet.co.za/jobad/za589075d2ad...  Mid_level 1-2 years
# ...                                                 ...                  ...
# 3925  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 1-2 years
# 3926  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 1-2 years
# 3927  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 3-5 years
# 3928  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 3-5 years
# 3929  https://www.indeed.com/rc/clk?jk=d4892583d4d1b...  Mid_level 1-2 years
#
#       number_days      date2  short_title province       country  \
# 0               0 2022-05-08          NaN  Gauteng  South Africa
# 1               2 2022-05-06          NaN  Gauteng  South Africa
# 2               3 2022-05-05          NaN  Gauteng  South Africa
# 3               3 2022-05-05          NaN  Gauteng  South Africa
# 4               3 2022-05-05          NaN  Gauteng  South Africa
# ...           ...        ...          ...      ...           ...
# 3925            3 2022-05-17          NaN   Remote        Remote
# 3926            3 2022-05-17          NaN   Remote        Remote
# 3927            3 2022-05-17          NaN   Remote        Remote
# 3928            3 2022-05-17          NaN   Remote        Remote
# 3929            3 2022-05-17          NaN   Remote        Remote
#
#                       real_title               summary_title
# 0     AWS Data Science Architect  AWS Data Science Architect
# 1                   Data Science                Data Science
# 2                   Data Science                Data Science
# 3                   Data Science                Data Science
# 4                   Data Science                Data Science
# ...                          ...                         ...
# 3925                Data Science                Data Science
# 3926                Data Science                Data Science
# 3927                Data Science                Data Science
# 3928                Data Science                Data Science
# 3929                Data Science                Data Science
#
# [8930 rows x 17 columns]

# %%
#create education feature

def education(x):
    type_edu = []
    education = ['bsc', 'honors', '11', '12', 'diploma', 'degree', 'nqf', 'masters', 'phd', 'prof', 'professor', 'grade']
    
    for word in x.lower().split():
        if word in education:
            type_edu.append(word)
    return ' '.join(type_edu)

# %%
joblisting['education'] =joblisting['job_desc'].apply(education)

# %%
def group_edu(x):
    if x == 'bsc' or x== 'degree':
        return 'degree/bsc'
    elif x == '11':
        return 'grade 11'
    elif x== '12':
        return 'grade 12'

# %%
joblisting['education'] =joblisting['job_desc'].apply(group_edu)

# %%
joblisting['education'].value_counts()

# %%
joblisting['location'].str.replace('[^\w\s]','')

# %%
joblisting['location'].iloc[6000].split()

# %%
def province(x):
    type_prov = []
    #x= x.str.replace('[^\w\s\d]',' ')
    provinces = ['gauteng','johannesburg', 'sandton','parktown','natal', 'limpopo', 'durban', 'kwazulu', 'midrand', 'stellenbosch','centurion','western','cape', 'pretoria','town', 'midrand' 'limpopo','north','west','eastern Cape','free' 'State','mpumalanga','northen cape']
    remote = []
    for word in x.lower().split():
        if word in provinces:
            type_prov.append(word)
        elif word not in provinces:
            remote.append(word)
    for y in type_prov:
        if y == 'johannesburg' or y == 'gauteng'or y == 'midrand' or  y == 'pretoria' or y == 'centurion':
            return 'Gauteng'
        elif y == 'stellenbosch'or y == 'western' or y ==  'cape':
            return 'Western Cape'
        elif y == 'durban' or y == 'kwazulu':
            return 'Kwazulu-Natal'
        elif y == 'limpopo':
            return 'Limpopo'
        elif y == 'eastern':
            return 'Eastern Cape'
        elif y== 'free state':
            return 'Free State'
        elif y== 'limpopo':
            return 'Limpopo'
        elif y == 'northen':
            return 'Northen' or 'cape'
        elif y== 'mpumalanga':
            return ' Mpumalanga'
        elif y == 'north' or 'west':
            return 'North West'
    for z in remote:
        if z in str(['united states','somerville', 'plano','dearborn','MI', 'sydney','NSW','Tampa','FL','Dallas','TX','San', 'Francisco','CA','Brooklyn','NY','US','Santa Clara','Seattle','WA','Plano','TX','New York City','NY','San Diego','Mountain View','CA','Livonia','MI','McLean','IL','Winter Park','FL']).lower():
            return 'Remote in the US'
        if z in str(['England','London','Cambridge','Manchester','Newcastle','Strand','Bristol Area','Bristol Area','Oxford','Birmingham','Nottingham','Liverpool','County Durham','England','Cambridge','Berkshire','Greater London']).lower():
            return 'Remote in England'
        if z in str(['AUE','Dubai,Abu Dhabi']).lower():
            return 'Remote in AUE'
        if z in str(['Autralia', 'Canberra','ACT']).lower():
            return 'Remote in Australia'
        if z in ['singapore']:
            return 'Remote in Singapore'
        else:
            return 'Remote'
                     

    #return ' '.join(remote)

# %%
joblisting['province']= joblisting['location'].apply(province)

# %%
def country(x):
    provinces = ['Gauteng', 'Limpopo', 'Western Cape', 'Free State', 'Eastern Cape', 'Kwazulu-Natal', 'Mpumalanga', 'North West', 'Northern Cape']
    if x in provinces:
        return 'South Africa'
    elif x == 'Remote in the US':
        return 'United States of America'
    elif x == 'Remote in England':
        return 'England'
    elif x=='Remote in AUE':
        return 'UAE'
    elif x== 'Remote in Singapore':
        return 'Singapore'
    elif x== 'Remote':
        return 'Remote'

# %%
joblisting['country']= joblisting['province'].apply(country)

# %%
joblisting.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  AWS Data Science Architect (QlikView & QlikSen...
# 1           1  Business Intelligence Developer (with Cloud an...
# 2           2                               Data science manager
# 3           3                               Data science manager
# 4           4  Business Intelligence Developer (with Cloud an...
#
#                    company               location  \
# 0        iSanqa Resourcing  Midrand, Johannesburg
# 1   e-Merge IT Recruitment  Johannesburg, Gauteng
# 2  Communicate Recruitment  Johannesburg, Gauteng
# 3  Communicate Recruitment  Johannesburg, Gauteng
# 4   e-Merge IT Recruitment  Johannesburg, Gauteng
#
#                                             job_desc date_posted  \
# 0  AWS Data Science Architect (QlikView & QlikSen...        None
# 1  An awesome opportunity is available for a Busi...  2 days ago
# 2  *Reference: CPM008305-THa-2*   Our client in f...  3 days ago
# 3  *Reference: CPM008305-RMo-1*   Our client in f...  3 days ago
# 4  An awesome opportunity is available for a Busi...  3 days ago
#
#   date_scrapped                     salary  \
# 0    2022-05-08                        NaN
# 1    2022-05-08                        NaN
# 2    2022-05-08  R620,000-700,000 per year
# 3    2022-05-08  R620,000-700,000 per year
# 4    2022-05-08                        NaN
#
#                                              job_url           experience  \
# 0  https://www.careerjet.co.za/jobad/zae5921d3d4a...  Mid_level 1-2 years
# 1  https://www.careerjet.co.za/jobad/zadbe4ba70e8...  Mid_level 1-2 years
# 2  https://www.careerjet.co.za/jobad/zae0c9b80b17...  Mid_level 1-2 years
# 3  https://www.careerjet.co.za/jobad/zab3ed08a036...  Mid_level 1-2 years
# 4  https://www.careerjet.co.za/jobad/za589075d2ad...  Mid_level 1-2 years
#
#    number_days      date2  short_title province       country  real_title
# 0            0 2022-05-08          NaN  Gauteng  South Africa         NaN
# 1            2 2022-05-06          NaN  Gauteng  South Africa         NaN
# 2            3 2022-05-05          NaN  Gauteng  South Africa         NaN
# 3            3 2022-05-05          NaN  Gauteng  South Africa         NaN
# 4            3 2022-05-05          NaN  Gauteng  South Africa         NaN

# %%
joblisting['country'].value_counts()

# %%
for word in joblisting['job_desc']:
    print(word)

# %%
#create skills feature

# %%
#create a country feature

# %%
#create a province feature

# %%
#create type of work feature

# %%
#gettin only the numerics

joblisting['number_days'] = joblisting['date_posted'].str.extract('(\d+)', expand=False)

# %%
joblisting

# %%
jobs_by_provinces = joblisting.groupby(['province', 'country', 'number_days'])[['title']].count().reset_index()

# %%
jobs_by_provinces
